# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.corpus import stopwords
stop = stopwords.words('english')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()


def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:    
        return None
      
def lemmatize_sentence(sentence):
    #tokenize the sentence and find the POS tag for each token
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))  
    #tuple of (token, wordnet_tag)
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            #if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:        
            #else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)


data = pd.read_json('D:/reviews_Cell_Phones_and_Accessories_5.json/Cell_Phones_and_Accessories_5.json', orient='records', lines = True)
print(data.head())

data['reviewText'] = data['summary'] + ' ' + data['reviewText']
print(data.head())

prods = data['asin'].unique()
print(len(prods))

temp = list(data[data['asin'] == prods[30]]['reviewText'])
print('no. of reviews:',len(temp))
vectorizer = CountVectorizer(ngram_range = (1,3), min_df = 2)
X = vectorizer.fit_transform(temp)
tags = vectorizer.get_feature_names()
cleaned_tags = [i for i in tags if i not in stop]
print(len(cleaned_tags), cleaned_tags)


#step-1
ind = [i for i in range(len(tags)) if tags[i] in cleaned_tags]
ind_sort = sorted(ind, key = lambda t: np.sum(X.toarray(), axis = 0)[t], reverse=True)
ultra_tags = [tags[i] for i in ind_sort[:30]]
print(len(ultra_tags), ultra_tags)

#step-2
temp_tags = []
for i in ultra_tags:
  if i.split()[0] in stop:
    temp_tags.append(' '.join(i.split()[1:]))
  else:
    temp_tags.append(i)
new_tags = [i for i in temp_tags if i not in stop]
print(len(new_tags), new_tags)

#step-3
lemmatize_tags = [lemmatize_sentence(i) for i in new_tags]
newer_tags = new_tags
if len(set(lemmatize_tags)) != len(lemmatize_tags):
  newer_tags = []
  new_tags.reverse()
  lemmatize_tags.reverse()
  for i in range(len(lemmatize_tags)):
    flag = 0
    for j in range(i+1, len(lemmatize_tags)):
      if lemmatize_tags[i]==lemmatize_tags[j]:
        flag = 1
        break
    if flag == 0:
      newer_tags.append(new_tags[i])
  newer_tags.reverse()
print(len(newer_tags), newer_tags)


#step-4
new_tags = []
newer_tags.reverse()
for i in range(len(newer_tags)):
  flag = 0
  synonyms = []
  for syn in wordnet.synsets(newer_tags[i]): 
    for l in syn.lemmas(): 
      synonyms.append(l.name())
  synonyms = list(set([i.replace('_', ' ',) for i in synonyms]))
  for j in range(i+1, len(newer_tags)):
    if newer_tags[j] in synonyms:
      flag = 1
      break
  if flag == 0:
    new_tags.append(newer_tags[i])
new_tags.reverse()
print(len(new_tags), new_tags)


#step-5
newer_tags = []
for i in range(len(new_tags)):
  flag = 0
  l = list(range(len(new_tags)))
  l.remove(i)
  for j in l:
    if new_tags[i] in new_tags[j] and len(new_tags[i]) < len(new_tags[j]):
      flag = 1
      break
  if flag == 0:
    newer_tags.append(new_tags[i])
print(len(newer_tags), newer_tags)
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  Looks Good They look good and stick good! I ju...        4
# 1  Really great product. These stickers work like...        5
# 2  LOVE LOVE LOVE These are awesome and make my p...        5
# 3  Cute! Item arrived in great time and was in pe...        4
# 4  leopard home button sticker for iphone 4s awes...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013
# 10429
# no. of reviews: 26
# 425 ['05', '747', '75', 'able', 'able to', 'adapter', 'adapters', 'adapters have', 'adjustable', 'adjusted', 'after few', 'also', 'am very', 'am very happy', 'and am', 'and am very', 'and it', 'and the', 'and when', 'appears', 'around', 'as the', 'audio', 'auto', 'auto reverse', 'back', 'back together', 'bad', 'be able', 'be able to', 'because it', 'been using', 'been using this', 'best', 'better', 'better sound', 'better than', 'bought', 'bought this', 'but it', 'but not', 'but will', 'buy', 'ca', 'ca 747', 'cable', 'can be', 'car', 'car stereo', 'car tape', 'case', 'cassette', 'cassette adapter', 'cassette player', 'cassette tape', 'cd', 'changed', 'changed to', 'cheap', 'clean', 'clear', 'clicking', 'clicking sound', 'coby', 'coby ca', 'coby ca 747', 'coby cassette', 'coiled', 'come', 'come out', 'come out of', 'connection', 'connector', 'cord', 'cord is', 'cost', 'costs', 'couple', 'couple of', 'decent', 'deck', 'deck and', 'depending', 'depending on', 'device', 'device to', 'did not', 'different', 'does not', 'don have', 'dual', 'dual position', 'easy', 'easy to', 'eject', 'end', 'even', 'excellent', 'expect', 'expect from', 'expect from cassette', 'far', 'feed', 'feedback', 'feet', 'figured', 'find', 'find the', 'fine', 'first', 'fix', 'fm', 'fm transmitter', 'for audio', 'for more', 'for more than', 'for my', 'for my car', 'for the', 'for the price', 'frequency', 'from cassette', 'from my', 'from the', 'get', 'get it', 'gets', 'getting', 'give', 'go', 'goes', 'good', 'good product', 'got', 'great', 'great and', 'great for', 'had any', 'had some', 'had to', 'happy', 'happy with', 'have an', 'have been', 'have been using', 'have not', 'have not had', 'have tape', 'have tape deck', 'have the', 'have to', 'hours', 'how to', 'idea', 'if there', 'if you', 'if your', 'if your tape', 'in my', 'in my car', 'in the', 'in the car', 'inside', 'instructions', 'ipod', 'is great', 'is not', 'is oriented', 'is the', 'issue', 'issues', 'it back', 'it doesn', 'it for', 'it has', 'it is', 'it makes', 'it out', 'it the', 'it this', 'it very', 'it was', 'it will', 'it worked', 'it would', 'item', 'keep', 'kind', 'kind of', 'like', 'like the', 'll get', 'long', 'look', 'looks', 'loose', 'lot', 'lot of', 'love', 'love it', 'made', 'makes', 'many', 'may', 'might', 'minutes', 'money', 'months', 'more than', 'mp3', 'mp3 player', 'mp3s', 'much', 'music', 'my car', 'my car tape', 'my money', 'my old', 'need', 'need to', 'negative', 'noise', 'normal', 'not had', 'not sure', 'not work', 'of the', 'of the car', 'of the other', 'of the tape', 'of use', 'off the', 'old', 'on my', 'on the', 'on your', 'on your tape', 'one', 'one for', 'oriented', 'out of', 'out of the', 'pay', 'pay for', 'phone', 'phone or', 'play', 'player', 'player and', 'player in', 'player in my', 'players', 'playing', 'plays', 'plug', 'plugged', 'plugged in', 'position', 'price', 'price sound', 'price sound quality', 'probably', 'problem', 'product', 'product have', 'product have been', 'properly', 'purchase', 'purchased', 'purchased this', 'put', 'put it', 'put it back', 'put the', 'quality', 'quality is', 'quickly', 'radio', 'really', 'remove', 'replace', 'reverse', 'reviews', 'see', 'shut', 'side', 'since', 'so if', 'so much', 'some of', 'some of the', 'something', 'sound', 'sound is', 'sound quality', 'sound quality is', 'sounds', 'sounds great', 'speakers', 'stereo', 'still', 'stuck', 'stuck in', 'stuck in my', 'sure', 'system', 'take', 'take it', 'tangled', 'tape', 'tape and', 'tape deck', 'tape deck and', 'tape player', 'tape players', 'that the', 'that the cord', 'that was', 'the adapter', 'the adjustable', 'the auto', 'the auto reverse', 'the best', 'the car', 'the cassette', 'the coby', 'the cord', 'the end', 'the fm', 'the only', 'the other', 'the player', 'the plug', 'the price', 'the price sound', 'the product', 'the radio', 'the sound', 'the sound quality', 'the tape', 'the tape and', 'the two', 'the volume', 'there is', 'there was', 'thing', 'things', 'think', 'this  ...
# 30 ['tape', 'sound', 'car', 'cassette', 'player', 'great', 'of the', 'adapter', 'product', 'good', 'quality', 'get', 'one', 'works', 'my car', 'reverse', 'sound quality', 'the tape', 'auto', 'cassette adapter', 'cord', 'in my', 'like', 'tape player', 'use', 'auto reverse', 'coby', 'deck', 'would', 'back']
# 28 ['tape', 'sound', 'car', 'cassette', 'player', 'great', 'adapter', 'product', 'good', 'quality', 'get', 'one', 'works', 'car', 'reverse', 'sound quality', 'tape', 'auto', 'cassette adapter', 'cord', 'like', 'tape player', 'use', 'auto reverse', 'coby', 'deck', 'would', 'back']
# 26 ['tape', 'sound', 'car', 'cassette', 'player', 'great', 'adapter', 'product', 'good', 'quality', 'get', 'one', 'works', 'reverse', 'sound quality', 'auto', 'cassette adapter', 'cord', 'like', 'tape player', 'use', 'auto reverse', 'coby', 'deck', 'would', 'back']
# 24 ['tape', 'sound', 'car', 'cassette', 'player', 'great', 'adapter', 'product', 'quality', 'get', 'one', 'works', 'reverse', 'sound quality', 'cassette adapter', 'cord', 'like', 'tape player', 'use', 'auto reverse', 'coby', 'deck', 'would', 'back']
# 17 ['car', 'great', 'product', 'get', 'one', 'works', 'sound quality', 'cassette adapter', 'cord', 'like', 'tape player', 'use', 'auto reverse', 'coby', 'deck', 'would', 'back']
